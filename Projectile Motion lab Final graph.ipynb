# %%
import numpy as np
import matplotlib.pyplot as plt


# %matplotlib inline


#Create arrays for your data
theta_array =  np.array([39.0, 42.0, 45.0, 48.0, 51.0])
ymean_array =  np.array([0.267, 0.419, 0.513, 0.667, 0.675])
yerr_array =  np.array([0.026, 0.011, 0.021, 0.006, 0.009])
#Create an array for your y-axis uncertainties

#Reassign variables
x = theta_array
y = ymean_array
dy = yerr_array

#size the plot
plt.figure(figsize=(15,10))

#create scatter plot
plt.scatter(x, y, color='blue', marker='o')

#create labels
plt.xlabel('Theta (degrees)')
plt.ylabel('Avg Height (m)')
plt.title('Projectile Motion')

plt.errorbar(x, y, yerr=dy, xerr=None, fmt="none")


#fitting to a 2nd degree polynomial
c,b,a=np.polynomial.polynomial.polyfit(x,y,2,w=dy)

#Annotate with values of A, B, C from best fit polynomial
plt.annotate('A = {value:.{digits}E}'.format(value=a, digits=3),
             (0.05, 0.9), xycoords='axes fraction')

plt.annotate('B = {value:.{digits}E}'.format(value=b, digits=3),
             (0.05, 0.85), xycoords='axes fraction')
             
plt.annotate('C = {value:.{digits}E}'.format(value=c, digits=3),
             (0.05, 0.8), xycoords='axes fraction')
#Create fit line
xnew = np.linspace(x.min(), x.max(), 300)
fit = a*xnew**2 + b*xnew +c

plt.scatter(xnew, fit, color='red')
plt.show()

print ("C = ",c , "B = ",b, "A = ",a)
# Out:
# C =  -3.5512413429111382 B =  0.1464184746169445 A =  -0.001243579969737462
